# %% [markdown]
# # Feature engineering
#
# ## 1. Load the dataset (train and test separately)
# ## 2. Column Name: Create new feature Title
# ## 3. Column Cabin : Create new feature Num_Cabs
# ## 4. Column Ticket : Create new feature Ticket_letters
# ## 5. Column SibSp and Parch : Create new feature TravelGroup
# ## . Save dataframe

# %% [markdown]
# ### Load python modules

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re

# %% [markdown]
# ## 1. Load the dataset (train and test separately)

# %%
train_data = './data/train.ETL.001.csv'
test_data = './data/test.ETL.001.csv'
df_train = pd.read_csv(train_data)
df_test = pd.read_csv(test_data)

# %%
df_train.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  missing        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  missing        S
# 3      0            113803  53.1000     C123        S
# 4      0            373450   8.0500  missing        S

# %%
df_test.head()
# Out:
#    Unnamed: 0  PassengerId  Pclass  \
# 0           0          892       3
# 1           1          893       3
# 2           2          894       2
# 3           3          895       3
# 4           4          896       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare    Cabin Embarked
# 0   330911   7.8292  missing        Q
# 1   363272   7.0000  missing        S
# 2   240276   9.6875  missing        Q
# 3   315154   8.6625  missing        S
# 4  3101298  12.2875  missing        S

# %%
df_test.count()  # check for missing values
# Out:
# Unnamed: 0     418
# PassengerId    418
# Pclass         418
# Name           418
# Sex            418
# Age            418
# SibSp          418
# Parch          418
# Ticket         418
# Fare           418
# Cabin          418
# Embarked       418
# dtype: int64

# %% [markdown]
# ## 2. Column Name: Create new feature Title
#
# As seen in the data exploration step, one can take the title in the name column as another feature. One needs to write a function to extract the name first. What titles are there? All titles have a . at the end.

# %%
def new_feature_title(row):
    # print(row['Name'])
    title = re.findall(r'\, (.*?)\.', row['Name'])[0]
    return title
    
df_train['Title'] = df_train.apply(lambda x: new_feature_title(x), axis = 1)
df_test['Title'] = df_test.apply(lambda x: new_feature_title(x), axis = 1)

# %%
df_train['Title'].unique().tolist()
# Out:
# ['Mr',
#  'Mrs',
#  'Miss',
#  'Master',
#  'Don',
#  'Rev',
#  'Dr',
#  'Mme',
#  'Ms',
#  'Major',
#  'Lady',
#  'Sir',
#  'Mlle',
#  'Col',
#  'Capt',
#  'the Countess',
#  'Jonkheer']

# %%
df_test['Title'].unique().tolist()
# Out:
# ['Mr', 'Mrs', 'Miss', 'Master', 'Ms', 'Col', 'Rev', 'Dr', 'Dona']

# %%
df_train[df_train.Name.str.contains('Jonkheer')]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 822         822          823         0       1
#
#                                 Name   Sex   Age  SibSp  Parch Ticket  Fare  \
# 822  Reuchlin, Jonkheer. John George  male  38.0      0      0  19972   0.0
#
#        Cabin Embarked     Title
# 822  missing        S  Jonkheer

# %% [markdown]
# The test set contains fewer titles compared to the training set. But all of the titles in the test set are in the training set. If the length is 891, that means all the titles in the test set are in the training set.

# %%
df_train['Title'].isin(df_test['Title']).count()
# Out:
# 891

# %% [markdown]
# ## 3. Column Cabin : Create new feature Num_Cabs

# %%
df_train[df_train.Cabin.str.contains('B', na=False)]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 31           31           32         1       1
# 54           54           55         0       1
# 61           61           62         1       1
# 118         118          119         0       1
# 139         139          140         0       1
# 170         170          171         0       1
# 194         194          195         1       1
# 195         195          196         1       1
# 257         257          258         1       1
# 263         263          264         0       1
# 291         291          292         1       1
# 299         299          300         1       1
# 311         311          312         1       1
# 329         329          330         1       1
# 369         369          370         1       1
# 390         390          391         1       1
# 435         435          436         1       1
# 484         484          485         1       1
# 487         487          488         0       1
# 504         504          505         1       1
# 520         520          521         1       1
# 523         523          524         1       1
# 536         536          537         0       1
# 539         539          540         1       1
# 540         540          541         1       1
# 587         587          588         1       1
# 632         632          633         1       1
# 641         641          642         1       1
# 671         671          672         0       1
# 679         679          680         1       1
# 689         689          690         1       1
# 690         690          691         1       1
# 730         730          731         1       1
# 737         737          738         1       1
# 742         742          743         1       1
# 745         745          746         0       1
# 759         759          760         1       1
# 763         763          764         1       1
# 779         779          780         1       1
# 781         781          782         1       1
# 789         789          790         0       1
# 802         802          803         1       1
# 815         815          816         0       1
# 820         820          821         1       1
# 829         829          830         1       1
# 872         872          873         0       1
# 887         887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female  35.0      1
# 54                      Ostby, Mr. Engelhart Cornelius    male  65.0      0
# 61                                 Icard, Miss. Amelie  female  38.0      0
# 118                           Baxter, Mr. Quigg Edmond    male  24.0      0
# 139                                 Giglio, Mr. Victor    male  24.0      0
# 170                          Van der hoef, Mr. Wyckoff    male  61.0      0
# 194          Brown, Mrs. James Joseph (Margaret Tobin)  female  44.0      0
# 195                               Lurette, Miss. Elise  female  58.0      0
# 257                               Cherry, Miss. Gladys  female  30.0      0
# 263                              Harrison, Mr. William    male  40.0      0
# 291            Bishop, Mrs. Dickinson H (Helen Walton)  female  19.0      1
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 311                         Ryerson, Miss. Emily Borie  female  18.0      2
# 329                       Hippach, Miss. Jean Gertrude  female  16.0      0
# 369                      Aubart, Mme. Leontine Pauline  female  24.0      0
# 390                         Carter, Mr. William Ernest    male  36.0      1
# 435                          Carter, Miss. Lucile Polk  female  14.0      1
# 484                            Bishop, Mr. Dickinson H    male  25.0      1
# 487                            Kent, Mr. Edward Austin    male  58.0      0
# 504                              Maioni, Miss. Roberta  female  16.0      0
# 520                              Perreault, Miss. Anne  female  30.0      0
# 523    Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female  44.0      0
# 536                  Butt, Major. Archibald Willingham    male  45.0      0
# 539                 Frolicher, Miss. Hedwig Margaritha  female  22.0      0
# 540                            Crosby, Miss. Harriet R  female  36.0      0
# 587                   Frolicher-Stehli, Mr. Maxmillian    male  60.0      1
# 632                          Stahelin-Maeglin, Dr. Max    male  32.0      0
# 641                               Sagesser, Mlle. Emma  female  24.0      0
# 671                             Davidson, Mr. Thornton    male  31.0      1
# 679                 Cardeza, Mr. Thomas Drake Martinez    male  36.0      0
# 689                  Madill, Miss. Georgette Alexandra  female  15.0      0
# 690                            Dick, Mr. Albert Adrian    male  31.0      1
# 730                      Allen, Miss. Elisabeth Walton  female  29.0      0
# 737                             Lesurer, Mr. Gustave J    male  35.0      0
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.0      2
# 745                       Crosby, Capt. Edward Gifford    male  70.0      1
# 759  Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0      0
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.0      1
# 779  Robert, Mrs. Edward Scott (Elisabeth Walton Mc...  female  43.0      0
# 781          Dick, Mrs. Albert Adrian (Vera Gillespie)  female  17.0      1
# 789                           Guggenheim, Mr. Benjamin    male  46.0      0
# 802                Carter, Master. William Thornton II    male  11.0      1
# 815                                   Fry, Mr. Richard    male  40.0      0
# 820  Hays, Mrs. Charles Melville (Clara Jennings Gr...  female  52.0      1
# 829          Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch      Ticket      Fare            Cabin Embarked         Title
# 31       0    PC 17569  146.5208              B78        C           Mrs
# 54       1      113509   61.9792              B30        C            Mr
# 61       0      113572   80.0000              B28  missing          Miss
# 118      1    PC 17558  247.5208          B58 B60        C            Mr
# 139      0    PC 17593   79.2000              B86        C            Mr
# 170      0      111240   33.5000              B19        S            Mr
# 194      0    PC 17610   27.7208               B4        C           Mrs
# 195      0    PC 17569  146.5208              B80        C          Miss
# 257      0      110152   86.5000              B77        S          Miss
# 263      0      112059    0.0000              B94        S            Mr
# 291      0       11967   91.0792              B49        C           Mrs
# 299      1    PC 17558  247.5208          B58 B60        C           Mrs
# 311      2    PC 17608  262.3750  B57 B59 B63 B66        C          Miss
# 329      1      111361   57.9792              B18        C          Miss
# 369      0    PC 17477   69.3000              B35        C           Mme
# 390      2      113760  120.0000          B96 B98        S            Mr
# 435      2      113760  120.0000          B96 B98        S          Miss
# 484      0       11967   91.0792              B49        C            Mr
# 487      0       11771   29.7000              B37        C            Mr
# 504      0      110152   86.5000              B79        S          Miss
# 520      0       12749   93.5000              B73        S          Miss
# 523      1      111361   57.9792              B18        C           Mrs
# 536      0      113050   26.5500              B38        S         Major
# 539      2       13568   49.5000              B39        C          Miss
# 540      2   WE/P 5735   71.0000              B22        S          Miss
# 587      1       13567   79.2000              B41        C            Mr
# 632      0       13214   30.5000              B50        C            Dr
# 641      0    PC 17477   69.3000              B35        C          Mlle
# 671      0  F.C. 12750   52.0000              B71        S            Mr
# 679      1    PC 17755  512.3292      B51 B53 B55        C            Mr
# 689      1       24160  211.3375               B5        S          Miss
# 690      0       17474   57.0000              B20        S            Mr
# 730      0       24160  211.3375               B5        S          Miss
# 737      0    PC 17755  512.3292             B101        C            Mr
# 742      2    PC 17608  262.3750  B57 B59 B63 B66        C          Miss
# 745      1   WE/P 5735   71.0000              B22        S          Capt
# 759      0      110152   86.5000              B77        S  the Countess
# 763      2      113760  120.0000          B96 B98        S           Mrs
# 779      1       24160  211.3375               B3        S           Mrs
# 781      0       17474   57.0000              B20        S           Mrs
# 789      0    PC 17593   79.2000          B82 B84        C            Mr
# 802      2      113760  120.0000          B96 B98        S        Master
# 815      0      112058    0.0000             B102        S            Mr
# 820      1       12749   93.5000              B69        S           Mrs
# 829      0      113572   80.0000              B28  missing           Mrs
# 872      0         695    5.0000      B51 B53 B55        S            Mr
# 887      0      112053   30.0000              B42        S          Miss

# %%
def new_feature_num_cabins(row):
    r = row['Cabin']
    t_ = re.findall(r'(\w\d\d)', r)
#     if len(t_) > 1:
#         print(t_)
    return len(t_)
    
df_train['Num_cabins'] = df_train.apply(lambda x: new_feature_num_cabins(x), axis=1)
df_train[df_train.Num_cabins > 1]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 27           27           28         0       1
# 88           88           89         1       1
# 97           97           98         1       1
# 118         118          119         0       1
# 297         297          298         0       1
# 299         299          300         1       1
# 305         305          306         1       1
# 311         311          312         1       1
# 341         341          342         1       1
# 390         390          391         1       1
# 435         435          436         1       1
# 438         438          439         0       1
# 498         498          499         0       1
# 679         679          680         1       1
# 700         700          701         1       1
# 742         742          743         1       1
# 763         763          764         1       1
# 789         789          790         0       1
# 802         802          803         1       1
# 872         872          873         0       1
#
#                                                   Name     Sex    Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.00      3
# 88                          Fortune, Miss. Mabel Helen  female  23.00      3
# 97                     Greenfield, Mr. William Bertram    male  23.00      0
# 118                           Baxter, Mr. Quigg Edmond    male  24.00      0
# 297                       Allison, Miss. Helen Loraine  female   2.00      1
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.00      0
# 305                     Allison, Master. Hudson Trevor    male   0.92      1
# 311                         Ryerson, Miss. Emily Borie  female  18.00      2
# 341                     Fortune, Miss. Alice Elizabeth  female  24.00      3
# 390                         Carter, Mr. William Ernest    male  36.00      1
# 435                          Carter, Miss. Lucile Polk  female  14.00      1
# 438                                  Fortune, Mr. Mark    male  64.00      1
# 498    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
# 679                 Cardeza, Mr. Thomas Drake Martinez    male  36.00      0
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.00      1
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.00      2
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.00      1
# 789                           Guggenheim, Mr. Benjamin    male  46.00      0
# 802                Carter, Master. William Thornton II    male  11.00      1
# 872                           Carlsson, Mr. Frans Olof    male  33.00      0
#
#      Parch    Ticket      Fare            Cabin Embarked   Title  Num_cabins
# 27       2     19950  263.0000      C23 C25 C27        S      Mr           3
# 88       2     19950  263.0000      C23 C25 C27        S    Miss           3
# 97       1  PC 17759   63.3583          D10 D12        C      Mr           2
# 118      1  PC 17558  247.5208          B58 B60        C      Mr           2
# 297      2    113781  151.5500          C22 C26        S    Miss           2
# 299      1  PC 17558  247.5208          B58 B60        C     Mrs           2
# 305      2    113781  151.5500          C22 C26        S  Master           2
# 311      2  PC 17608  262.3750  B57 B59 B63 B66        C    Miss           4
# 341      2     19950  263.0000      C23 C25 C27        S    Miss           3
# 390      2    113760  120.0000          B96 B98        S      Mr           2
# 435      2    113760  120.0000          B96 B98        S    Miss           2
# 438      4     19950  263.0000      C23 C25 C27        S      Mr           3
# 498      2    113781  151.5500          C22 C26        S     Mrs           2
# 679      1  PC 17755  512.3292      B51 B53 B55        C      Mr           3
# 700      0  PC 17757  227.5250          C62 C64        C     Mrs           2
# 742      2  PC 17608  262.3750  B57 B59 B63 B66        C    Miss           4
# 763      2    113760  120.0000          B96 B98        S     Mrs           2
# 789      0  PC 17593   79.2000          B82 B84        C      Mr           2
# 802      2    113760  120.0000          B96 B98        S  Master           2
# 872      0       695    5.0000      B51 B53 B55        S      Mr           3

# %%
df_test['Num_cabins'] = df_test.apply(lambda x: new_feature_num_cabins(x), axis=1)
df_train[df_train.Num_cabins > 1]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 27           27           28         0       1
# 88           88           89         1       1
# 97           97           98         1       1
# 118         118          119         0       1
# 297         297          298         0       1
# 299         299          300         1       1
# 305         305          306         1       1
# 311         311          312         1       1
# 341         341          342         1       1
# 390         390          391         1       1
# 435         435          436         1       1
# 438         438          439         0       1
# 498         498          499         0       1
# 679         679          680         1       1
# 700         700          701         1       1
# 742         742          743         1       1
# 763         763          764         1       1
# 789         789          790         0       1
# 802         802          803         1       1
# 872         872          873         0       1
#
#                                                   Name     Sex    Age  SibSp  \
# 27                      Fortune, Mr. Charles Alexander    male  19.00      3
# 88                          Fortune, Miss. Mabel Helen  female  23.00      3
# 97                     Greenfield, Mr. William Bertram    male  23.00      0
# 118                           Baxter, Mr. Quigg Edmond    male  24.00      0
# 297                       Allison, Miss. Helen Loraine  female   2.00      1
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.00      0
# 305                     Allison, Master. Hudson Trevor    male   0.92      1
# 311                         Ryerson, Miss. Emily Borie  female  18.00      2
# 341                     Fortune, Miss. Alice Elizabeth  female  24.00      3
# 390                         Carter, Mr. William Ernest    male  36.00      1
# 435                          Carter, Miss. Lucile Polk  female  14.00      1
# 438                                  Fortune, Mr. Mark    male  64.00      1
# 498    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
# 679                 Cardeza, Mr. Thomas Drake Martinez    male  36.00      0
# 700  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female  18.00      1
# 742              Ryerson, Miss. Susan Parker "Suzette"  female  21.00      2
# 763          Carter, Mrs. William Ernest (Lucile Polk)  female  36.00      1
# 789                           Guggenheim, Mr. Benjamin    male  46.00      0
# 802                Carter, Master. William Thornton II    male  11.00      1
# 872                           Carlsson, Mr. Frans Olof    male  33.00      0
#
#      Parch    Ticket      Fare            Cabin Embarked   Title  Num_cabins
# 27       2     19950  263.0000      C23 C25 C27        S      Mr           3
# 88       2     19950  263.0000      C23 C25 C27        S    Miss           3
# 97       1  PC 17759   63.3583          D10 D12        C      Mr           2
# 118      1  PC 17558  247.5208          B58 B60        C      Mr           2
# 297      2    113781  151.5500          C22 C26        S    Miss           2
# 299      1  PC 17558  247.5208          B58 B60        C     Mrs           2
# 305      2    113781  151.5500          C22 C26        S  Master           2
# 311      2  PC 17608  262.3750  B57 B59 B63 B66        C    Miss           4
# 341      2     19950  263.0000      C23 C25 C27        S    Miss           3
# 390      2    113760  120.0000          B96 B98        S      Mr           2
# 435      2    113760  120.0000          B96 B98        S    Miss           2
# 438      4     19950  263.0000      C23 C25 C27        S      Mr           3
# 498      2    113781  151.5500          C22 C26        S     Mrs           2
# 679      1  PC 17755  512.3292      B51 B53 B55        C      Mr           3
# 700      0  PC 17757  227.5250          C62 C64        C     Mrs           2
# 742      2  PC 17608  262.3750  B57 B59 B63 B66        C    Miss           4
# 763      2    113760  120.0000          B96 B98        S     Mrs           2
# 789      0  PC 17593   79.2000          B82 B84        C      Mr           2
# 802      2    113760  120.0000          B96 B98        S  Master           2
# 872      0       695    5.0000      B51 B53 B55        S      Mr           3

# %% [markdown]
# ## 4. Column Ticket : Create new feature Ticket_letters
#
# As seen in data exploration, some tickets have some letters before the ticket, others only have digits. Might be useful as a feature.
#
# Assumption:
#
# - only the letters before the / are relevant until the .
# - decision to remove letters LP and AQ from the test set, because those letters are not in the training set

# %%
def unique_letters(row):
    pat = re.findall(r'([^\d]+)\d', row) # match only those that contains letters before digits
    if len(pat) > 0:
        pat = re.findall(r'([^\/]+)', pat[0]) # stop at / 
        pat = [s.replace('.', '') for s in pat] # remove .
        return pat[0].strip() # remove whitespace
    return 'digits'  # not a letter

df_train['Ticket_letters'] = df_train['Ticket'].apply(lambda x: unique_letters(x))
df_test['Ticket_letters'] = df_test['Ticket'].apply(lambda x: unique_letters(x))
df_train['Ticket_letters'].unique()
# Out:
# array(['A', 'PC', 'STON', 'digits', 'PP', 'CA', 'SC', 'SP', 'SOC', 'SO',
#        'W', 'SOTON', 'WEP', 'C', 'SOP', 'Fa', 'FCC', 'SW', 'SCO', 'P',
#        'WE', 'FC'], dtype=object)

# %%
df_test['Ticket_letters'].unique()
# Out:
# array(['digits', 'A', 'WEP', 'SC', 'STON', 'PC', 'C', 'CA', 'W', 'SOTON',
#        'FCC', 'FC', 'PP', 'SO', 'SOC', 'AQ', 'LP'], dtype=object)

# %%
letters_test_set = df_test['Ticket_letters'].unique().tolist()

# %%
for letter in letters_test_set:
    my_sum = (df_train['Ticket_letters'].isin([letter]).sum())
    if my_sum == 0:
        print(f'Letter {letter} is in the test set but not in the dataset!')
# Out:
# Letter AQ is in the test set but not in the dataset!
# Letter LP is in the test set but not in the dataset!

# %%
df_test[df_test.Ticket.str.contains('AQ')]
# Out:
#      Unnamed: 0  PassengerId  Pclass                  Name     Sex   Age  \
# 256         256         1148       3       Mahon, Mr. John    male  24.0
# 315         315         1207       3  Hagardon, Miss. Kate  female  17.0
#
#      SibSp  Parch       Ticket    Fare    Cabin Embarked Title  Num_cabins  \
# 256      0      0    AQ/4 3130  7.7500  missing        Q    Mr           0
# 315      0      0  AQ/3. 30631  7.7333  missing        Q  Miss           0
#
#     Ticket_letters
# 256             AQ
# 315             AQ

# %%
df_test[df_test.Ticket.str.contains('LP')]
# Out:
#      Unnamed: 0  PassengerId  Pclass                 Name   Sex   Age  SibSp  \
# 312         312         1204       3  Sadowitz, Mr. Harry  male  24.0      0
#
#      Parch   Ticket   Fare    Cabin Embarked Title  Num_cabins Ticket_letters
# 312      0  LP 1588  7.575  missing        S    Mr           0             LP

# %%
forbidden_letters= ['AQ', 'LP']

def new_feature_ticket_letters(row):
    pat = re.findall(r'([^\d]+)\d', row['Ticket']) # match only those that contains letters before digits
    if len(pat) > 0:
        pat = re.findall(r'([^\/]+)', pat[0]) # stop at / 
        pat = [s.replace('.', '') for s in pat] # remove .
        res = pat[0].strip() # remove whitespace
        if res in forbidden_letters:
            return 'missing'
        else:
            return res
    return 'digits'  # not a letter

df_train['Ticket_letters'] = df_train.apply(lambda x: new_feature_ticket_letters(x), axis=1)
df_test['Ticket_letters'] = df_test.apply(lambda x: new_feature_ticket_letters(x), axis=1)
df_train.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked Title  Num_cabins  \
# 0      0         A/5 21171   7.2500  missing        S    Mr           0
# 1      0          PC 17599  71.2833      C85        C   Mrs           1
# 2      0  STON/O2. 3101282   7.9250  missing        S  Miss           0
# 3      0            113803  53.1000     C123        S   Mrs           1
# 4      0            373450   8.0500  missing        S    Mr           0
#
#   Ticket_letters
# 0              A
# 1             PC
# 2           STON
# 3         digits
# 4         digits

# %%
df_test[df_test.Ticket_letters.str.contains('miss')]
# Out:
#      Unnamed: 0  PassengerId  Pclass                  Name     Sex   Age  \
# 256         256         1148       3       Mahon, Mr. John    male  24.0
# 312         312         1204       3   Sadowitz, Mr. Harry    male  24.0
# 315         315         1207       3  Hagardon, Miss. Kate  female  17.0
#
#      SibSp  Parch       Ticket    Fare    Cabin Embarked Title  Num_cabins  \
# 256      0      0    AQ/4 3130  7.7500  missing        Q    Mr           0
# 312      0      0      LP 1588  7.5750  missing        S    Mr           0
# 315      0      0  AQ/3. 30631  7.7333  missing        Q  Miss           0
#
#     Ticket_letters
# 256        missing
# 312        missing
# 315        missing

# %%
df_train[df_train.Ticket_letters.str.contains('miss')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title, Num_cabins, Ticket_letters]
# Index: []

# %% [markdown]
# ## 5. Column SibSp and Parch: Create new feature TravelGroup
#
# Feature to indciate the number of passengers that travel in a group, i.e. the number of siblings/spouses or parents with that passenger. This is created very simplistic, taking only the sum of number of siblings/spouses and parents with that passenger.
#
# Looking at the histogram, it is not a good idea to use continuous values, instead one can categorize the travel group into four classes:
#
# - Alone: Passenger travels not in a group
# - Duo: Passengers travel in a group of 2 (1 including passenger)
# - GroupSmall: Passengers travel in a group of size between 3 and 4 (2, 3 including passenger)
# - GroupLarge: Passengers travel in a group of size larger than 5 (4 including passenger)

# %%
def feature_travelgroup(row):
    return (row['SibSp'] + row['Parch'])

df_train['TravelGroup'] = df_train.apply(lambda x: feature_travelgroup(x), axis=1)
df_test['TravelGroup'] = df_test.apply(lambda x: feature_travelgroup(x), axis=1)


print(np.max(df_train.TravelGroup))
print(np.max(df_test.TravelGroup))
# Out:
# 10
# 10

# %%
# Quick check on the histogram
plt.figure()
plt.title('New feature TravelGroup histogram')
bins = np.arange(0,10+1,1)-0.5
plt.xlim(-0.5,10.5)
Y = [df_train['TravelGroup'].values, df_test['TravelGroup'].values]
color = ['green', 'red']
label = ['train', 'test']
n, bins, patches = plt.hist(x=Y, stacked=True, color=color, bins=bins, alpha=0.7, rwidth=0.85, density=False, label=label)
plt.grid(axis='y', alpha=0.75)
plt.legend(title='Dataset')
plt.xlabel('TravelGroup')
plt.ylabel('Counts')


# plt.figure()
# Out:
# Text(0,0.5,'Counts')

# %%
def new_feature_travelgroup(row):
    n = (row['SibSp'] + row['Parch'])
    if n == 0:
        return 'Alone'
    if (n == 1):
        return 'Duo'
    if (n > 1) & (n < 4):
        return 'GroupSmall'
    if (n > 4):
        return 'GroupLarge'

df_train['TravelGroup'] = df_train.apply(lambda x: new_feature_travelgroup(x), axis=1)
df_test['TravelGroup'] = df_test.apply(lambda x: new_feature_travelgroup(x), axis=1)
# Out:
#   File "<ipython-input-87-e645c9afb3ed>", line 4
#     if n == 0:
#      ^
# SyntaxError: invalid syntax

# %%
df_test[df_test['TravelGroup'].str.contains('Alone', na=False)]
# Out:
#      Unnamed: 0  PassengerId  Pclass  \
# 0             0          892       3
# 2             2          894       2
# 3             3          895       3
# 5             5          897       3
# 6             6          898       3
# 8             8          900       3
# 10           10          902       3
# 11           11          903       1
# 16           16          908       2
# 17           17          909       3
# 19           19          911       3
# 22           22          914       1
# 27           27          919       3
# 28           28          920       1
# 35           35          927       3
# 36           36          928       3
# 37           37          929       3
# 38           38          930       3
# 39           39          931       3
# 41           41          933       1
# 42           42          934       3
# 43           43          935       2
# 45           45          937       3
# 46           46          938       1
# 47           47          939       3
# 48           48          940       1
# 51           51          943       2
# 54           54          946       2
# 56           56          948       3
# 57           57          949       3
# ..          ...          ...     ...
# 367         367         1259       3
# 369         369         1261       2
# 371         371         1263       1
# 372         372         1264       1
# 373         373         1265       2
# 375         375         1267       1
# 377         377         1269       2
# 378         378         1270       1
# 380         380         1272       3
# 381         381         1273       3
# 382         382         1274       3
# 384         384         1276       2
# 386         386         1278       3
# 387         387         1279       2
# 388         388         1280       3
# 390         390         1282       1
# 393         393         1285       2
# 396         396         1288       3
# 398         398         1290       3
# 399         399         1291       3
# 400         400         1292       1
# 403         403         1295       1
# 405         405         1297       2
# 408         408         1300       3
# 410         410         1302       3
# 412         412         1304       3
# 413         413         1305       3
# 414         414         1306       1
# 415         415         1307       3
# 416         416         1308       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 5                          Svensson, Mr. Johan Cervin    male  14.0      0
# 6                                Connolly, Miss. Kate  female  30.0      0
# 8           Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 10                                   Ilieff, Mr. Ylio    male  24.0      0
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 16                                  Keane, Mr. Daniel    male  35.0      0
# 17                                  Assaf, Mr. Gerios    male  21.0      0
# 19              Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0
# 22               Flegenheim, Mrs. Alfred (Antoinette)  female  41.0      0
# 27                                  Daher, Mr. Shedid    male  22.5      0
# 28                            Brady, Mr. John Bertram    male  41.0      0
# 35   Katavelas, Mr. Vassilios (Catavelas Vassilios")"    male  18.5      0
# 36                                Roth, Miss. Sarah A  female  22.0      0
# 37                                 Cacic, Miss. Manda  female  21.0      0
# 38                                    Sap, Mr. Julius    male  25.0      0
# 39                                      Hee, Mr. Ling    male  24.0      0
# 41                        Franklin, Mr. Thomas Parham    male  42.0      0
# 42                              Goldsmith, Mr. Nathan    male  41.0      0
# 43              Corbett, Mrs. Walter H (Irene Colvin)  female  30.0      0
# 45                    Peltomaki, Mr. Nikolai Johannes    male  25.0      0
# 46                           Chevre, Mr. Paul Romaine    male  45.0      0
# 47                           Shaughnessy, Mr. Patrick    male  24.0      0
# 48    Bucknell, Mrs. William Robert (Emma Eliza Ward)  female  60.0      0
# 51                                 Pulbaum, Mr. Franz    male  27.0      0
# 54                  Mangiavacchi, Mr. Serafino Emilio    male  28.0      0
# 56                                    Cor, Mr. Bartol    male  35.0      0
# 57                      Abelseth, Mr. Olaus Jorgensen    male  25.0      0
# ..                                                ...     ...   ...    ...
# 367      Riihivouri, Miss. Susanna Juhantytar Sanni""  female  22.0      0
# 369                     Pallas y Castello, Mr. Emilio    male  29.0      0
# 371                         Wilson, Miss. Helen Alice  female  31.0      0
# 372                           Ismay, Mr. Joseph Bruce    male  49.0      0
# 373                            Harbeck, Mr. William H    male  44.0      0
# 375                          Bowen, Miss. Grace Scott  female  45.0      0
# 377                      Cotterill, Mr. Henry Harry""    male  21.0      0
# 378                       Hipkins, Mr. William Edward    male  55.0      0
# 380                             O'Connor, Mr. Patrick    male  24.0      0
# 381                                 Foley, Mr. Joseph    male  26.0      0
# 382                        Risien, Mrs. Samuel (Emma)  female  22.0      0
# 384                    Wheeler, Mr. Edwin Frederick""    male  28.0      0
# 386                    Aronsson, Mr. Ernst Axel Algot    male  24.0      0
# 387                                   Ashby, Mr. John    male  57.0      0
# 388                              Canavan, Mr. Patrick    male  21.0      0
# 390                        Payne, Mr. Vivian Ponsonby    male  23.0      0
# 393                              Gilbert, Mr. William    male  47.0      0
# 396                              Colbert, Mr. Patrick    male  24.0      0
# 398                    Larsson-Rondberg, Mr. Edvard A    male  22.0      0
# 399                          Conlon, Mr. Thomas Henry    male  31.0      0
# 400                           Bonnell, Miss. Caroline  female  30.0      0
# 403                            Carrau, Mr. Jose Pedro    male  17.0      0
# 405      Nourney, Mr. Alfred (Baron von Drachstedt")"    male  20.0      0
# 408                   Riordan, Miss. Johanna Hannah""  female  22.0      0
# 410                            Naughton, Miss. Hannah  female  22.0      0
# 412                    Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                                Spector, Mr. Woolf    male  24.0      0
# 414                      Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415                      Saether, Mr. Simon Sivertsen    male  38.5      0
# 416                               Ware, Mr. Frederick    male  24.0      0
#
#      Parch              Ticket      Fare        Cabin Embarked Title  \
# 0        0              330911    7.8292      missing        Q    Mr
# 2        0              240276    9.6875      missing        Q    Mr
# 3        0              315154    8.6625      missing        S    Mr
# 5        0                7538    9.2250      missing        S    Mr
# 6        0              330972    7.6292      missing        Q  Miss
# 8        0                2657    7.2292      missing        C   Mrs
# 10       0              349220    7.8958      missing        S    Mr
# 11       0                 694   26.0000      missing        S    Mr
# 16       0              233734   12.3500      missing        Q    Mr
# 17       0                2692    7.2250      missing        C    Mr
# 19       0                2696    7.2250      missing        C   Mrs
# 22       0            PC 17598   31.6833      missing        S   Mrs
# 27       0                2698    7.2250      missing        C    Mr
# 28       0              113054   30.5000          A21        S    Mr
# 35       0                2682    7.2292      missing        C    Mr
# 36       0              342712    8.0500      missing        S  Miss
# 37       0              315087    8.6625      missing        S  Miss
# 38       0              345768    9.5000      missing        S    Mr
# 39       0                1601   56.4958      missing        S    Mr
# 41       0              113778   26.5500          D34        S    Mr
# 42       0  SOTON/O.Q. 3101263    7.8500      missing        S    Mr
# 43       0              237249   13.0000      missing        S   Mrs
# 45       0   STON/O 2. 3101291    7.9250      missing        S    Mr
# 46       0            PC 17594   29.7000           A9        C    Mr
# 47       0              370374    7.7500      missing        Q    Mr
# 48       0               11813   76.2917          D15        C   Mrs
# 51       0       SC/PARIS 2168   15.0333      missing        C    Mr
# 54       0         SC/A.3 2861   15.5792      missing        C    Mr
# 56       0              349230    7.8958      missing        S    Mr
# 57       0              348122    7.6500        F G63        S    Mr
# ..     ...                 ...       ...          ...      ...   ...
# 367      0             3101295   39.6875      missing        S  Miss
# 369      0       SC/PARIS 2147   13.8583      missing        C    Mr
# 371      0               16966  134.5000      E39 E41        C  Miss
# 372      0              112058    0.0000  B52 B54 B56        S    Mr
# 373      0              248746   13.0000      missing        S    Mr
# 375      0            PC 17608  262.3750      missing        C  Miss
# 377      0               29107   11.5000      missing        S    Mr
# 378      0                 680   50.0000          C39        S    Mr
# 380      0              366713    7.7500      missing        Q    Mr
# 381      0              330910    7.8792      missing        Q    Mr
# 382      0              364498   14.5000      missing        S   Mrs
# 384      0       SC/PARIS 2159   12.8750      missing        S    Mr
# 386      0              349911    7.7750      missing        S    Mr
# 387      0              244346   13.0000      missing        S    Mr
# 388      0              364858    7.7500      missing        Q    Mr
# 390      0               12749   93.5000          B24        S    Mr
# 393      0          C.A. 30769   10.5000      missing        S    Mr
# 396      0              371109    7.2500      missing        Q    Mr
# 398      0              347065    7.7750      missing        S    Mr
# 399      0               21332    7.7333      missing        Q    Mr
# 400      0               36928  164.8667           C7        S  Miss
# 403      0              113059   47.1000      missing        S    Mr
# 405      0       SC/PARIS 2166   13.8625          D38        C    Mr
# 408      0              334915    7.7208      missing        Q  Miss
# 410      0              365237    7.7500      missing        Q  Miss
# 412      0              347086    7.7750      missing        S  Miss
# 413      0           A.5. 3236    8.0500      missing        S    Mr
# 414      0            PC 17758  108.9000         C105        C  Dona
# 415      0  SOTON/O.Q. 3101262    7.2500      missing        S    Mr
# 416      0              359309    8.0500      missing        S    Mr
#
#      Num_cabins Ticket_letters TravelGroup
# 0             0         digits       Alone
# 2             0         digits       Alone
# 3             0         digits       Alone
# 5             0         digits       Alone
# 6             0         digits       Alone
# 8             0         digits       Alone
# 10            0         digits       Alone
# 11            0         digits       Alone
# 16            0         digits       Alone
# 17            0         digits       Alone
# 19            0         digits       Alone
# 22            0             PC       Alone
# 27            0         digits       Alone
# 28            1         digits       Alone
# 35            0         digits       Alone
# 36            0         digits       Alone
# 37            0         digits       Alone
# 38            0         digits       Alone
# 39            0         digits       Alone
# 41            1         digits       Alone
# 42            0          SOTON       Alone
# 43            0         digits       Alone
# 45            0           STON       Alone
# 46            0             PC       Alone
# 47            0         digits       Alone
# 48            1         digits       Alone
# 51            0             SC       Alone
# 54            0             SC       Alone
# 56            0         digits       Alone
# 57            1         digits       Alone
# ..          ...            ...         ...
# 367           0         digits       Alone
# 369           0             SC       Alone
# 371           2         digits       Alone
# 372           3         digits       Alone
# 373           0         digits       Alone
# 375           0             PC       Alone
# 377           0         digits       Alone
# 378           1         digits       Alone
# 380           0         digits       Alone
# 381           0         digits       Alone
# 382           0         digits       Alone
# 384           0             SC       Alone
# 386           0         digits       Alone
# 387           0         digits       Alone
# 388           0         digits       Alone
# 390           1         digits       Alone
# 393           0             CA       Alone
# 396           0         digits       Alone
# 398           0         digits       Alone
# 399           0         digits       Alone
# 400           0         digits       Alone
# 403           0         digits       Alone
# 405           1             SC       Alone
# 408           0         digits       Alone
# 410           0         digits       Alone
# 412           0         digits       Alone
# 413           0              A       Alone
# 414           1             PC       Alone
# 415           0          SOTON       Alone
# 416           0         digits       Alone
#
# [253 rows x 16 columns]

# %%
df_test.head()
# Out:
#    Unnamed: 0  PassengerId  Pclass  \
# 0           0          892       3
# 1           1          893       3
# 2           2          894       2
# 3           3          895       3
# 4           4          896       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare    Cabin Embarked Title  Num_cabins Ticket_letters  \
# 0   330911   7.8292  missing        Q    Mr           0         digits
# 1   363272   7.0000  missing        S   Mrs           0         digits
# 2   240276   9.6875  missing        Q    Mr           0         digits
# 3   315154   8.6625  missing        S    Mr           0         digits
# 4  3101298  12.2875  missing        S   Mrs           0         digits
#
#   TravelGroup
# 0       Alone
# 1         Duo
# 2       Alone
# 3       Alone
# 4  GroupSmall
